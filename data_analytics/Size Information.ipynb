# %%
# !pip install ipython-sql==0.4.1
# !pip install SQLAlchemy==1.4.49
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 8.8 MB/s eta 0:00:00
# ...
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13696 sha256=25ea6b349cc08a3c1f92bc6a4a3778af6e05c2e89fc7fa172202944d68dbafa7
#   Stored in directory: /root/.cache/pip/wheels/25/4b/07/18c5d92824315576e478206ea69df34a9e31958f6143eb0e31
# Successfully built prettytable
# ...
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.9.0
#     Uninstalling prettytable-3.9.0:
#       Successfully uninstalled prettytable-3.9.0
#   Attempting uninstall: ipython-sql
#     Found existing installation: ipython-sql 0.5.0
#     Uninstalling ipython-sql-0.5.0:
#       Successfully uninstalled ipython-sql-0.5.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 7.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.23
#     Uninstalling SQLAlchemy-2.0.23:
# ...

# %%
# !pip install pandas pandasql

import pandas as pd
import pandasql as psql
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26772 sha256=02e5e626c7b839013f3daee19f5d071e58e67c6d2643b5d2c2e3e977353a5ae2
#   Stored in directory: /root/.cache/pip/wheels/e9/bc/3a/8434bdcccf5779e72894a9b24fecbdcaf97940607eaf4bcdf9
# Successfully built pandasql
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
# raw_data로부터 product_info.csv 읽기
info = pd.read_csv('drive/My Drive/Musinsa Standard DashBoard/raw_data/product_info.csv')

# raw_data로부터 recommend_data.csv 읽기
size = pd.read_csv('drive/My Drive/Musinsa Standard DashBoard/raw_data/recommend_data.csv')

# %%
size_info = size.merge(info[['product_id', 'category1', 'category2']], on='product_id', how='inner')
size_info = size_info[['recom_id', 'product_id', 'category1', 'category2', 'gender', 'height', 'weight', 'keyword', 'size']]
size_info
# Out:
#       recom_id   product_id category1 category2 gender  height  weight  \
# 0            1  MMCCT701-BK       아우터  겨울 싱글 코트     남자     182      81
# 1            2  MMCCT701-BK       아우터  겨울 싱글 코트     남자     178      65
# 2            3  MMCCT701-BK       아우터  겨울 싱글 코트     남자     180      80
# 3            4  MMCCT701-BK       아우터  겨울 싱글 코트     남자     181      65
# 4            5  MMCCT701-BK       아우터  겨울 싱글 코트     여자     170      70
# ...        ...          ...       ...       ...    ...     ...     ...
# 3929      3938  MMCCT703-BK       아우터  겨울 기타 코트     남자     173      70
# 3930      3939  MMCCT703-BK       아우터  겨울 기타 코트     남자     178      60
# 3931      3940  MMCCT703-BK       아우터  겨울 기타 코트     남자     188      95
# 3932      3941  MMCCT703-BK       아우터  겨울 기타 코트     남자     183     105
# 3933      3942  MMCCT703-BK       아우터  겨울 기타 코트     남자     187      87
#
#      keyword  size
# 0        적당함    M
# 1          큼   XL
# 2        적당함    L
# 3        적당함    L
# ...

# %%
size_info.to_csv('Size_Information.csv', index=False)
